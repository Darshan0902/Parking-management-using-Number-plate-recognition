# %% [markdown]
# <a href="https://colab.research.google.com/github/Darshan0902/Parking-management-using-Number-plate-recognition./blob/main/CAR_IMAGE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 14.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="omuIheE81rZpDLFZJcNC")
project = rf.workspace().project("license-plate-recognition-rxg4e")
model = project.version(4).model

# infer on a local image
print(model.predict("/content/1.jpg", confidence=40, overlap=30).json())

# visualize your prediction
model.predict("/content/1.jpg", confidence=40, overlap=30).save("prediction.jpg")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# {'predictions': [{'x': 1062, 'y': 486, 'width': 204, 'height': 75, 'confidence': 0.8500871062278748, 'class': 'License_Plate', 'class_id': 0, 'detection_id': '1fbc75a9-cdb6-47fa-a1f8-79ee0882bbdd', 'image_path': '/content/1.jpg', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '1280', 'height': '720'}}

# %%
import easyocr

# Initialize the EasyOCR Reader
reader = easyocr.Reader(['en'])  # You can specify the language as needed

# Load the image
image_path = "1.jpg"

# Perform character recognition
results = reader.readtext(image_path)

# Print the recognized text
if results:
    for (text, _, _) in results:
        print("Recognized Text:", text)
else:
    print("No text detected in the image.")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Recognized Text: [[308, 420], [336, 420], [336, 444], [308, 444]]
# Recognized Text: [[990, 464], [1080, 464], [1080, 516], [990, 516]]
# Recognized Text: [[336.4647122724278, 429.07296418074014], [392.99007438041997, 451.800992561958], [385.5352877275722, 468.92703581925986], [329.00992561958003, 446.199007438042]]
# Recognized Text: [[1071.4188611699158, 460.25658350974743], [1151.0766360131886, 452.10499761382255], [1153.5811388300842, 499.74341649025257], [1073.9233639868114, 506.89500238617745]]

# %%
from google.colab.patches import cv2_imshow
import cv2 as cv
#Replace cv2.imshow() to cv2_imshow()
img = cv.imread('1.jpg') #mentioning a path of an image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
pip install pytesseract

# %%
pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 17.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 34.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 17.4 MB/s eta 0:00:00
# ...

# %%
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% CompleteRecognized Text: [[145, 1], [169, 1], [169, 17], [145, 17]]
# Recognized Text: [[197, 23], [229, 23], [229, 37], [197, 37]]
# Recognized Text: [[0, 76], [38, 76], [38, 102], [0, 102]]
# Recognized Text: [[407, 1051], [530, 1051], [530, 1078], [407, 1078]]
# ...

# %%
pip install easyocr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.3/908.3 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 16.7 MB/s eta 0:00:00
# ...
